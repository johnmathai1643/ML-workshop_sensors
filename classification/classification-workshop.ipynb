# %% [markdown]
# # Implementing logistic regression to build a Spam Filter
#
# The goal of this workshop is to implement your own logistic regression classifier and build a Spam filter. You will:
#
#  * Extract features from Email Spam database.
#  * Convert an DataFrame into a NumPy array.
#  * Implement the link function for logistic regression.
#  * Write a function to compute the derivative of the log likelihood function with respect to a single coefficient.
#  * Implement gradient ascent.
#  * Given a set of coefficients, predict spam or non-spam.
#  * Compute classification accuracy for the logistic regression model.
#
# Let's get started!

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ## Load review dataset
# For this application, we will use a email spam database from UCI data repos. The subset was chosen to contain similar numbers of spam and non spam messages

# %%
email = pd.read_csv('email_fresh_1953', sep=',')
# email = pd.read_csv('email_collection', sep='\t', names=["type", "message"])

# email_ham_messages = email[email['type']=='ham'].head(1206)
# email_spam_messages = email[email['type']=='spam']

# email_messages_fresh = email_spam_messages.append(email_ham_messages,ignore_index = True)
# email_messages_fresh.to_csv("email_fresh_1953",sep=',',index=False)

#email['label'] = email['type'].apply(lambda type : +1 if type == 'ham' else -1)
#email_spam_messages['message'].to_csv("email_spam_messages_1953",sep=',',index=False)
#email_ham_messages = email[email['label']==+1]
#email_ham_messages['message'].to_csv("email_ham_messages_1953",sep=',',index=False)


#email = email.reindex(np.random.permutation(email.index))
email
# Out:
#       type                                            message
# 0     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 1     spam  FreeMsg Hey there darling it's been 3 week's n...
# 2     spam  WINNER!! As a valued network customer you have...
# 3     spam  Had your mobile 11 months or more? U R entitle...
# 4     spam  SIX chances to win CASH! From 100 to 20,000 po...
# 5     spam  URGENT! You have won a 1 week FREE membership ...
# 6     spam  XXXMobileMovieClub: To use your credit, click ...
# 7     spam  England v Macedonia - dont miss the goals/team...
# 8     spam  Thanks for your subscription to Ringtone UK yo...
# 9     spam  07732584351 - Rodger Burns - MSG = We tried to...
# 10    spam  SMS. ac Sptv: The New Jersey Devils and the De...
# 11    spam  Congrats! 1 year special cinema pass for 2 is ...
# 12    spam  As a valued customer, I am pleased to advise y...
# 13    spam  Urgent UR awarded a complimentary trip to Euro...
# 14    spam  Did you hear about the new "Divorce Barbie"? I...
# 15    spam  Please call our customer service representativ...
# 16    spam  Your free ringtone is waiting to be collected....
# 17    spam  GENT! We are trying to contact you. Last weeke...
# 18    spam  You are a winner U have been specially selecte...
# 19    spam  PRIVATE! Your 2004 Account Statement for 07742...
# 20    spam  URGENT! Your Mobile No. was awarded £2000 Bonu...
# 21    spam  Todays Voda numbers ending 7548 are selected t...
# 22    spam  Sunshine Quiz Wkly Q! Win a top Sony DVD playe...
# 23    spam  Want 2 get laid tonight? Want real Dogging loc...
# 24    spam  You'll not rcv any more msgs from the chat svc...
# 25    spam  FreeMsg Why haven't you replied to my text? I'...
# 26    spam  Customer service annoncement. You have a New Y...
# 27    spam  You are a winner U have been specially selecte...
# 28    spam  -PLS STOP bootydelious (32/F) is inviting you ...
# 29    spam  BangBabes Ur order is on the way. U SHOULD rec...
# ...    ...                                                ...
# 1923   ham                            We're finally ready fyi
# 1924   ham           Auntie huai juan never pick up her phone
# 1925   ham                          Ya tel, wats ur problem..
# 1926   ham                             i dnt wnt to tlk wid u
# 1927   ham  We spend our days waiting for the ideal path t...
# 1928   ham  Its ok my arm is feeling weak cuz i got a shot...
# 1929   ham  Please reserve ticket on saturday eve from che...
# 1930   ham  Storming msg: Wen u lift d phne, u say "HELLO"...
# 1931   ham  That's ok. I popped in to ask bout something a...
# 1932   ham                        All e best 4 ur exam later.
# 1933   ham  Hope ur head doesn't hurt 2 much ! Am ploughin...
# 1934   ham     Oh k.i think most of wi and nz players unsold.
# 1935   ham  Haha... Where got so fast lose weight, thk muz...
# 1936   ham  I wonder how you got online, my love ? Had you...
# 1937   ham                Haha just kidding, papa needs drugs
# 1938   ham  Thk shld b can... Ya, i wana go 4 lessons... H...
# 1939   ham                                            Oh ok..
# 1940   ham               R we still meeting 4 dinner tonight?
# 1941   ham  Thats cool! I am a gentleman and will treat yo...
# 1942   ham                           Shall i start from hear.
# 1943   ham  Then we wait 4 u lor... No need 2 feel bad lar...
# 1944   ham   No did you check? I got his detailed message now
# 1945   ham  You have registered Sinco as Payee. Log in at ...
# 1946   ham  No, I decided that only people who care about ...
# 1947   ham  Kaiez... Enjoy ur tuition... Gee... Thk e seco...
# 1948   ham  You have registered Sinco as Payee. Log in at ...
# 1949   ham   cool. We will have fun practicing making babies!
# 1950   ham         Actually getting ready to leave the house.
# 1951   ham                           K..k..any special today?
# 1952   ham                     Then we gotta do it after that
#
# [1953 rows x 2 columns]

# %% [markdown]
# One column of this dataset is 'label', corresponding to the class label with +1 indicating a non-spam message and -1 indicating a spam message.

# %%
email['label'] = email['type'].apply(lambda type : +1 if type == 'ham' else -1)
email
# Out:
#       type                                            message  label
# 0     spam  Free entry in 2 a wkly comp to win FA Cup fina...     -1
# 1     spam  FreeMsg Hey there darling it's been 3 week's n...     -1
# 2     spam  WINNER!! As a valued network customer you have...     -1
# 3     spam  Had your mobile 11 months or more? U R entitle...     -1
# 4     spam  SIX chances to win CASH! From 100 to 20,000 po...     -1
# 5     spam  URGENT! You have won a 1 week FREE membership ...     -1
# 6     spam  XXXMobileMovieClub: To use your credit, click ...     -1
# 7     spam  England v Macedonia - dont miss the goals/team...     -1
# 8     spam  Thanks for your subscription to Ringtone UK yo...     -1
# 9     spam  07732584351 - Rodger Burns - MSG = We tried to...     -1
# 10    spam  SMS. ac Sptv: The New Jersey Devils and the De...     -1
# 11    spam  Congrats! 1 year special cinema pass for 2 is ...     -1
# 12    spam  As a valued customer, I am pleased to advise y...     -1
# 13    spam  Urgent UR awarded a complimentary trip to Euro...     -1
# 14    spam  Did you hear about the new "Divorce Barbie"? I...     -1
# 15    spam  Please call our customer service representativ...     -1
# 16    spam  Your free ringtone is waiting to be collected....     -1
# 17    spam  GENT! We are trying to contact you. Last weeke...     -1
# 18    spam  You are a winner U have been specially selecte...     -1
# 19    spam  PRIVATE! Your 2004 Account Statement for 07742...     -1
# 20    spam  URGENT! Your Mobile No. was awarded £2000 Bonu...     -1
# 21    spam  Todays Voda numbers ending 7548 are selected t...     -1
# 22    spam  Sunshine Quiz Wkly Q! Win a top Sony DVD playe...     -1
# 23    spam  Want 2 get laid tonight? Want real Dogging loc...     -1
# 24    spam  You'll not rcv any more msgs from the chat svc...     -1
# 25    spam  FreeMsg Why haven't you replied to my text? I'...     -1
# 26    spam  Customer service annoncement. You have a New Y...     -1
# 27    spam  You are a winner U have been specially selecte...     -1
# 28    spam  -PLS STOP bootydelious (32/F) is inviting you ...     -1
# 29    spam  BangBabes Ur order is on the way. U SHOULD rec...     -1
# ...    ...                                                ...    ...
# 1923   ham                            We're finally ready fyi      1
# 1924   ham           Auntie huai juan never pick up her phone      1
# 1925   ham                          Ya tel, wats ur problem..      1
# 1926   ham                             i dnt wnt to tlk wid u      1
# 1927   ham  We spend our days waiting for the ideal path t...      1
# 1928   ham  Its ok my arm is feeling weak cuz i got a shot...      1
# 1929   ham  Please reserve ticket on saturday eve from che...      1
# 1930   ham  Storming msg: Wen u lift d phne, u say "HELLO"...      1
# 1931   ham  That's ok. I popped in to ask bout something a...      1
# 1932   ham                        All e best 4 ur exam later.      1
# 1933   ham  Hope ur head doesn't hurt 2 much ! Am ploughin...      1
# 1934   ham     Oh k.i think most of wi and nz players unsold.      1
# 1935   ham  Haha... Where got so fast lose weight, thk muz...      1
# 1936   ham  I wonder how you got online, my love ? Had you...      1
# 1937   ham                Haha just kidding, papa needs drugs      1
# 1938   ham  Thk shld b can... Ya, i wana go 4 lessons... H...      1
# 1939   ham                                            Oh ok..      1
# 1940   ham               R we still meeting 4 dinner tonight?      1
# 1941   ham  Thats cool! I am a gentleman and will treat yo...      1
# 1942   ham                           Shall i start from hear.      1
# 1943   ham  Then we wait 4 u lor... No need 2 feel bad lar...      1
# 1944   ham   No did you check? I got his detailed message now      1
# 1945   ham  You have registered Sinco as Payee. Log in at ...      1
# 1946   ham  No, I decided that only people who care about ...      1
# 1947   ham  Kaiez... Enjoy ur tuition... Gee... Thk e seco...      1
# 1948   ham  You have registered Sinco as Payee. Log in at ...      1
# 1949   ham   cool. We will have fun practicing making babies!      1
# 1950   ham         Actually getting ready to leave the house.      1
# 1951   ham                           K..k..any special today?      1
# 1952   ham                     Then we gotta do it after that      1
#
# [1953 rows x 3 columns]

# %% [markdown]
# Let us quickly explore more of this dataset.  The 'name' column indicates the name of the product.  Here we list the first 10 products in the dataset.  We then count the number of positive and negative reviews.

# %%
print '# of non-spam messages =', len(email[email['label']==1])
print '# of spam messages =', len(email[email['label']==-1])
# Out:
# # of non-spam messages = 1206
# # of spam messages = 747

# %% [markdown]
# ## Apply text cleaning on the message data
#
# In this section, we will perform some simple feature cleaning using dataframes. We compiled a list of most frequent words into a JSON file.
#
# Now, we will load these words from this JSON file:

# %%
import json
with open('important_words.json', 'r') as f: # Reads the list of most frequent words
    important_words = json.load(f)
important_words = [str(s) for s in important_words]
print important_words
# Out:
# ['all', 'code', 'sch', '1500', 'TEXT', 'AGE', 'month', 'More', 'Does', 'sleep', 'oso', 'go', 'liao', 'O2', 'Today', 'content', 'Someone', 'tv', 'send', 'to', 'finally', 'does', 'toClaim', 'Not', 'smile', 'Latest', 'worth', 'sent', 'And', 'yr', 'chennai', 'Prize', 'very', 'Sky', 'Last', 'anyway', '150p', 'every', '2000', 'Aight', 'word', 'ticket', '12hrs', 'Where', 'minute', 'cool', 'Enjoy', 'school', 'prize', 'Just', 'did', 'gettin', 'eve', 'No1', 'leave', 'ONLY', 'Text', 'Go', 'Ufind', 'havent', 'Pound', 'TsCs', 'dis', 'nokia', 'TO', 'says', 'specially', 'videochat', 'tired', 'phones', 'Terms', 'direct', 'Should', 'second', 'cost', 'video', 'voucher', 'picked', 'pass', 'download', 'run', 'rentl', '3G', 'Expires', 'blue', '9AE', 'Calls', 'rate', 'giving', 'Videophones', 'selected', 'access', 'waiting', 'CAMERA', 'abt', 'SIM', 'goes', 'reply', 'net', 'told', 'Me', 'full', 'TONE', 'Gift', 'leh', 'Yup', 'here', 'Congratulations', 'Ibiza', 'met', 'FLAG', 'let', 'pub', 'making', 'Alright', 'sexy', 'Abiola', 'Wkly', 'My', 'Camcorder', 'change', 'wait', 'ME', 'sending', 'great', 'ahead', 'discount', 'auction', '9am11pm', 'SPTyrone', 'pics', 'credit', 'Cant', 'smoke', 'pick', 'Dear', 'NOW', 'MY', 'Uve', 'thats', 'wif', 'via', 'love', 'family', '150pmin', 'win', 'app', 'When', 'POLY', 'Update', 'ask', 'wit', 'RowW1JHL', '1st', 'apply', 'txt', 'REVEAL', 'Rreveal', 'usf', 'use', 'charge', 'from', 'takes', 'working', 'ec2a', 'httpwwwurawinnercom', 'FRND', 'visit', 'two', 'by', 'few', 'live', 'camera', 'music', 'msg', 'wwwgetzedcouk', 'until', 'today', 'more', 'sort', 'babe', 'knows', 'Gud', 'started', 'company', 'award', 'hurt', 'phone', 'flag', '2optout', 'So', '150ptone', 'charged', 'baby', 'iPod', 'hold', 'Txt', 'must', 'town', 'Claim', 'account', 'valued', 'join', 'LIKE', 'hour', 'player', 'car', 'quoting', 'work', 'NTT', 'Day', 'yer', 'Video', 'den', 'following', 'meet', 'arrive', 'didnt', 'Your', 'numbers', 'spree', 'heart', 'figure', 'messages', 'admirer', 'something', 'Digital', 'DATE', 'b4', 'times', 'YOUR', 'Our', 'sir', 'Xmas', '900', 'end', 'Yo', 'Missing', 'Ya', 'country', 'purpose', 'watching', 'UKs', '11mths', 'till', 'hot', 'Hope', 'aft', 'boytoy', 'Why', 'pizza', 'CW25WX', 'tried', 'information', 'stop', 'after', 'collection', 'lucky', 'Will', 'birthday', 'MUSIC', 'HMV', 'coming', 'date', 'mah', '150pMsg', 'rcvd', 'guys', 'lar', 'man', 'All', 'complimentary', 'attempt', 'remember', 'Netcollex', 'maybe', 'Watching', 'UNLIMITED', 'age16', 'anytime', 'Bonus', 'so', 'things', 'noline', 'POBox334', 'Speak', 'DOUBLE', 'order', 'talk', 'UR', 'What', 'Gr8', 'tkts', 'help', 'office', 'vary', 'soon', 'Same', 'years', 'GO', 'isnt', 'paper', 'hell', 'still', 'wun', 'before', 'W45WQ', 'SonyEricsson', 'SAE', 'NOKIA', 'better', 'fromm', 'offers', 'choose', 'Santa', 'mail', 'bout', 'holiday', 'might', 'happened', 'Cs', 'good', 'ya', 'noe', 'URN', 'POBox', 'vouchers', 'break', 'lunch', 'Can', 'they', 'half', '300', 'one', 'rental', 'day', 'POBox36504W45WQ', 'wont', 'ENGLAND', 'name', 'always', 'mrng', 'someone', 'doesnt', 'Thanks', 'rock', 'went', 'Sol', 'side', 'carlos', 'mean', 'either', 'From', 'CHAT', 'weight', 'doing', 'house', 'eg', 'hard', 'SERVICES', 'Msg', 'used', 'forgot', '2day', 'logo', 'girl', 'calling', 'saturday', 'special', 'really', 'try', 'network', 'driving', 'rply', 'open', 'ha', 'Welcome', 'Haha', 'looking', 're', 'Tenants', 'got', 'cause', 'IS', 'shows', 'log', 'await', 'wwwringtonescouk', 'goto', '150ppm', 'ENG', 'This', 'POBOX', 'story', 'free', 'quite', 'UK', 'WON', 'Delivery', 'latest', 'put', 'wanted', 'princess', 'care', 'LDN', 'Ugh', 'dunno', 'could', 'hes', 'kiss', 'days', 'keep', 'thing', 'place', 'Chat', 'swing', 'onto', 'think', 'first', 'already', 'FREEPHONE', 'dont', 'feel', 'GUARANTEED', 'There', 'Please', 'number', 'fancy', 'yourself', 'Going', 'done', 'another', '', 'unredeemed', 'reached', 'message', 'miss', 'tomorrow', 'Break', 'little', 'txtin', 'service', 'revealed', 'top', '3wk', 'girls', 'tot',  ...

# %% [markdown]
# Now, we will perform 2 simple data transformations:
#
# 1. Remove punctuation using [Python's built-in](https://docs.python.org/2/library/string.html) string functionality.
# 2. Compute word counts (only for **important_words**)
#
# We start with *Step 1* which can be done as follows:

# %%
def remove_punctuation(text):
    import string
    return text.translate(None, string.punctuation) 

email['message_clean'] = email['message'].apply(remove_punctuation)

# %% [markdown]
# Now we proceed with Step 2. For each word in important_words, we compute a count for the number of times the word occurs in each message. We will store this count in a separate column (one for each word). The result of this feature processing is a single column for each word in important_words which keeps a count of the number of times the respective word occurs in the review text.
# (also known as one-hot encoding.)
#
#
# Note: There are several ways of doing this. In this assignment, we use the built-in count function for Python lists. Each review string is first split into individual words and the number of occurances of a given word is counted.

# %%
# this might take a while
for word in important_words:
    email[word] = email['message_clean'].apply(lambda s : s.split().count(word))

# %% [markdown]
# The dataFrame **email** now contains one column for each of the **important_words**. As an example, the column **"FREE"** contains a count of the number of times the word **"FREE"** occurs in each of the messages.

# %%
len(email[email['FREE'] >= 1])
# Out:
# 93

# %% [markdown]
# ## Convert DataFrame to NumPy array
#
# As you have seen previously, NumPy is a powerful library for doing matrix manipulation. Let us convert our data to matrices and then implement our algorithms with matrices.
#
# First, make sure you can perform the following import.

# %%
import numpy as np

# %% [markdown]
# We now provide you with a function that extracts columns from an DataFrame and converts them into a NumPy array. Two arrays are returned: one representing features and another representing class labels. Note that the feature matrix includes an additional column 'intercept' to take account of the intercept term.

# %%
def get_numpy_data(data_sframe, features, label):
    data_sframe['intercept'] = 1
    features = ['intercept'] + features
    features_sframe = data_sframe[features]
    feature_matrix = features_sframe.as_matrix()
    label_sarray = data_sframe[label]
    label_array = label_sarray.as_matrix()
    return(feature_matrix, label_array)

# %% [markdown]
# Let us convert the data into NumPy arrays.

# %%
# Warning: This may take a few minutes...
feature_matrix, label = get_numpy_data(email, important_words, 'label')

# %%
feature_matrix.shape
# Out:
# (1953, 1135)

# %% [markdown]
# Now, let us see what the **label** column looks like:

# %%
label
# Out:
# array([-1, -1, -1, ...,  1,  1,  1])

# %% [markdown]
# ## Estimating conditional probability with link function
# Recall from lecture that the link function is given by:
# $$
# P(y_i = +1 | \mathbf{x}_i,\mathbf{w}) = \frac{1}{1 + \exp(-\mathbf{w}^T h(\mathbf{x}_i))},
# $$
#
# where the feature vector $h(\mathbf{x}_i)$ represents the word counts of **important_words** in the review  $\mathbf{x}_i$. Complete the following function that implements the link function:

# %%
'''
produces probablistic estimate for P(y_i = +1 | x_i, w).
estimate ranges between 0 and 1.
'''
def predict_probability(feature_matrix, coefficients):
    # Take dot product of feature_matrix and coefficients  
    # YOUR CODE HERE
    hx = np.dot(feature_matrix,coefficients)
    
    # Compute P(y_i = +1 | x_i, w) using the link function
    # YOUR CODE HERE
    predictions = 1.0/(1 + np.exp(-hx))
    
    # return predictions
    return predictions

# %% [markdown]
# **Aside**. How the link function works with matrix algebra
#
# Since the word counts are stored as columns in **feature_matrix**, each $i$-th row of the matrix corresponds to the feature vector $h(\mathbf{x}_i)$:
# $$
# [\text{feature_matrix}] =
# \left[
# \begin{array}{c}
# h(\mathbf{x}_1)^T \\
# h(\mathbf{x}_2)^T \\
# \vdots \\
# h(\mathbf{x}_N)^T
# \end{array}
# \right] =
# \left[
# \begin{array}{cccc}
# h_0(\mathbf{x}_1) & h_1(\mathbf{x}_1) & \cdots & h_D(\mathbf{x}_1) \\
# h_0(\mathbf{x}_2) & h_1(\mathbf{x}_2) & \cdots & h_D(\mathbf{x}_2) \\
# \vdots & \vdots & \ddots & \vdots \\
# h_0(\mathbf{x}_N) & h_1(\mathbf{x}_N) & \cdots & h_D(\mathbf{x}_N)
# \end{array}
# \right]
# $$
#
# By the rules of matrix multiplication, the score vector containing elements $\mathbf{w}^T h(\mathbf{x}_i)$ is obtained by multiplying **feature_matrix** and the coefficient vector $\mathbf{w}$.
# $$
# [\text{score}] =
# [\text{feature_matrix}]\mathbf{w} =
# \left[
# \begin{array}{c}
# h(\mathbf{x}_1)^T \\
# h(\mathbf{x}_2)^T \\
# \vdots \\
# h(\mathbf{x}_N)^T
# \end{array}
# \right]
# \mathbf{w}
# = \left[
# \begin{array}{c}
# h(\mathbf{x}_1)^T\mathbf{w} \\
# h(\mathbf{x}_2)^T\mathbf{w} \\
# \vdots \\
# h(\mathbf{x}_N)^T\mathbf{w}
# \end{array}
# \right]
# = \left[
# \begin{array}{c}
# \mathbf{w}^T h(\mathbf{x}_1) \\
# \mathbf{w}^T h(\mathbf{x}_2) \\
# \vdots \\
# \mathbf{w}^T h(\mathbf{x}_N)
# \end{array}
# \right]
# $$

# %% [markdown]
# ## Compute derivative of log likelihood with respect to a single coefficient
#
# Recall from lecture:
# $$
# \frac{\partial\ell}{\partial w_j} = \sum_{i=1}^N h_j(\mathbf{x}_i)\left(\mathbf{1}[y_i = +1] - P(y_i = +1 | \mathbf{x}_i, \mathbf{w})\right)
# $$
#
# We will now write a function that computes the derivative of log likelihood with respect to a single coefficient $w_j$. The function accepts two arguments:
# * `errors` vector containing $\mathbf{1}[y_i = +1] - P(y_i = +1 | \mathbf{x}_i, \mathbf{w})$ for all $i$.
# * `feature` vector containing $h_j(\mathbf{x}_i)$  for all $i$.
#
# Complete the following code block:

# %%
def feature_derivative(errors, feature):     
    # Compute the dot product of errors and feature
    derivative = np.dot(errors,feature)
    # Return the derivative
    return derivative
# Out:
# [False False False ...,  True  True  True]

# %% [markdown]
# In the main lecture, our focus was on the likelihood.  In the advanced optional video, however, we introduced a transformation of this likelihood---called the log likelihood---that simplifies the derivation of the gradient and is more numerically stable.  Due to its numerical stability, we will use the log likelihood instead of the likelihood to assess the algorithm.
#
# The log likelihood is computed using the following formula (see the advanced optional video if you are curious about the derivation of this equation):
#
# $$\ell\ell(\mathbf{w}) = \sum_{i=1}^N \Big( (\mathbf{1}[y_i = +1] - 1)\mathbf{w}^T h(\mathbf{x}_i) - \ln\left(1 + \exp(-\mathbf{w}^T h(\mathbf{x}_i))\right) \Big) $$
#
# We provide a function to compute the log likelihood for the entire dataset.

# %%
def compute_log_likelihood(feature_matrix, label, coefficients):
    indicator = (label==+1)
    scores = np.dot(feature_matrix, coefficients)
    logexp = np.log(1. + np.exp(-scores))
    
    # Simple check to prevent overflow
    mask = np.isinf(logexp)
    logexp[mask] = -scores[mask]

    lp = np.sum((indicator-1)*scores - logexp)
    return lp

# %% [markdown]
# ## Taking gradient steps
# Now we are ready to implement our own logistic regression. All we have to do is to write a gradient ascent function that takes gradient steps towards the optimum.
#
# Complete the following function to solve the logistic regression model using gradient ascent:

# %%
from math import sqrt

def logistic_regression(feature_matrix, label, initial_coefficients, step_size, max_iter):
    coefficients = np.array(initial_coefficients) # make sure it's a numpy array
    for itr in xrange(max_iter):

        # Predict P(y_i = +1|x_i,w) using your predict_probability() function
        # YOUR CODE HERE
        predictions = predict_probability(feature_matrix,initial_coefficients)
        
        # Compute indicator value for (y_i = +1)
        indicator = (label==+1)
        
        # Compute the errors as indicator - predictions
        errors = indicator - predictions
        for j in xrange(len(coefficients)): # loop over each coefficient
            
            # Recall that feature_matrix[:,j] is the feature column associated with coefficients[j].
            # Compute the derivative for coefficients[j]. Save it in a variable called derivative
            # YOUR CODE HERE
            derivative = feature_derivative(errors, feature_matrix[:,j])
            
            # add the step size times the derivative to the current coefficient
            ## YOUR CODE HERE
            coefficients[j] = coefficients[j] + step_size*derivative
        
        # Checking whether log likelihood is increasing
        if itr <= 15 or (itr <= 100 and itr % 10 == 0) or (itr <= 1000 and itr % 100 == 0) \
        or (itr <= 10000 and itr % 1000 == 0) or itr % 10000 == 0:
            lp = compute_log_likelihood(feature_matrix, label, coefficients)
            print 'iteration %*d: log likelihood of observed labels = %.8f' % \
                (int(np.ceil(np.log10(max_iter))), itr, lp)
    return coefficients

# %% [markdown]
# Now, let us run the logistic regression solver.

# %%
coefficients = logistic_regression(feature_matrix, label, initial_coefficients=np.zeros(feature_matrix.shape[1]),
                                   step_size=1e-5, max_iter=951)
# Out:
# [False False False ..., False False False]
# iteration   0: log likelihood of observed labels = -1352.39170405
# [False False False ..., False False False]
# iteration   1: log likelihood of observed labels = -1351.06902028
# [False False False ..., False False False]
# iteration   2: log likelihood of observed labels = -1349.74839233
# [False False False ..., False False False]
# iteration   3: log likelihood of observed labels = -1348.42982018
# [False False False ..., False False False]
# iteration   4: log likelihood of observed labels = -1347.11330380
# [False False False ..., False False False]
# iteration   5: log likelihood of observed labels = -1345.79884316
# [False False False ..., False False False]
# iteration   6: log likelihood of observed labels = -1344.48643822
# [False False False ..., False False False]
# iteration   7: log likelihood of observed labels = -1343.17608894
# [False False False ..., False False False]
# iteration   8: log likelihood of observed labels = -1341.86779527
# [False False False ..., False False False]
# iteration   9: log likelihood of observed labels = -1340.56155715
# [False False False ..., False False False]
# iteration  10: log likelihood of observed labels = -1339.25737452
# [False False False ..., False False False]
# iteration  11: log likelihood of observed labels = -1337.95524730
# [False False False ..., False False False]
# iteration  12: log likelihood of observed labels = -1336.65517541
# [False False False ..., False False False]
# iteration  13: log likelihood of observed labels = -1335.35715878
# [False False False ..., False False False]
# iteration  14: log likelihood of observed labels = -1334.06119730
# [False False False ..., False False False]
# iteration  15: log likelihood of observed labels = -1332.76729088
# [False False False ..., False False False]
# iteration  20: log likelihood of observed labels = -1326.32858073
# [False False False ..., False False False]
# iteration  30: log likelihood of observed labels = -1313.60521354
# [False False False ..., False False False]
# iteration  40: log likelihood of observed labels = -1301.08709580
# [False False False ..., False False False]
# iteration  50: log likelihood of observed labels = -1288.77398261
# [False False False ..., False False False]
# iteration  60: log likelihood of observed labels = -1276.66556174
# [False False False ..., False False False]
# iteration  70: log likelihood of observed labels = -1264.76145413
# [False False False ..., False False False]
# iteration  80: log likelihood of observed labels = -1253.06121445
# [False False False ..., False False False]
# iteration  90: log likelihood of observed labels = -1241.56433183
# [False False False ..., False False False]
# iteration 100: log likelihood of observed labels = -1230.27023068
# [False False False ..., False False False]
# iteration 200: log likelihood of observed labels = -1128.31132792
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-e9447a0ebe98> in <module>()
#       1 coefficients = logistic_regression(feature_matrix, label, initial_coefficients=np.zeros(feature_matrix.shape[1]),
# ----> 2                                    step_size=1e-5, max_iter=951)
#
# <ipython-input-67-e01549f9c771> in logistic_regression(feature_matrix, label, initial_coefficients, step_size, max_iter)
#       7         # Predict P(y_i = +1|x_i,w) using your predict_probability() function
#       8         # YOUR CODE HERE
# ----> 9         predictions = predict_probability(feature_matrix,initial_coefficients)
#      10
#      11         # Compute indicator value for (y_i = +1)
#
# <ipython-input-48-a27fa68eefa1> in predict_probability(feature_matrix, coefficients)
#       6     # Take dot product of feature_matrix and coefficients
#       7     # YOUR CODE HERE
# ----> 8     hx = np.dot(feature_matrix,coefficients)
#       9
#      10     # Compute P(y_i = +1 | x_i, w) using the link function
#
# KeyboardInterrupt:

# %% [markdown]
# ## Predicting the labels
#
# Recall from lecture that class predictions for a data point $\mathbf{x}$ can be computed from the coefficients $\mathbf{w}$ using the following formula:
# $$
# \hat{y}_i =
# \left\{
# \begin{array}{ll}
#       +1 & \mathbf{x}_i^T\mathbf{w} > 0 \\
#       -1 & \mathbf{x}_i^T\mathbf{w} \leq 0 \\
# \end{array}
# \right.
# $$
#
# Now, we will write some code to compute class predictions. We will do this in two steps:
# * **Step 1**: First compute the **scores** using **feature_matrix** and **coefficients** using a dot product.
# * **Step 2**: Using the formula above, compute the class predictions from the scores.
#
# Step 1 can be implemented as follows:

# %%
# Compute the scores as a dot product between feature_matrix and coefficients.
scores = np.dot(feature_matrix, coefficients)
scores
predicted_label = []
for i in range(len(scores)):
    if scores[i] > 0:
        predicted_label.append(1)
    else:
        predicted_label.append(-1)
predicted_label = np.array(predicted_label)
predicted_label
predicted_positive = (predicted_label==+1).sum()

# %%
predicted_positive
# Out:
# 1624

# %% [markdown]
# ## Measuring accuracy
#
# We will now measure the classification accuracy of the model. Recall from the lecture that the classification accuracy can be computed as follows:
#
# $$
# \mbox{accuracy} = \frac{\mbox{# correctly classified data points}}{\mbox{# total data points}}
# $$
#
# Complete the following code block to compute the accuracy of the model.

# %%
correct = predicted_label*label
correct = (correct==+1).sum()
num_mistakes = len(predicted_label) - correct 

accuracy = 1.0 * correct / len(label)
print "-----------------------------------------------------"
print '# Reviews   correctly classified =', len(email) - num_mistakes
print '# Reviews incorrectly classified =', num_mistakes
print '# Reviews total                  =', len(email)
print "-----------------------------------------------------"
print 'Accuracy = %.2f' % accuracy
# Out:
# -----------------------------------------------------
# # Reviews   correctly classified = 1509
# # Reviews incorrectly classified = 444
# # Reviews total                  = 1953
# -----------------------------------------------------
# Accuracy = 0.77

# %%
scores = np.dot(feature_matrix, coefficients)
scores
# Out:
# array([-2.306175,  0.60864 , -0.84639 , ...,  1.3314  ,  2.26338 ,
#         2.534415])

# %%
coefficients = list(coefficients[1:]) # exclude intercept
word_coefficient_tuples = [(word, coefficient) for word, coefficient in zip(important_words, coefficients)]
word_coefficient_tuples = sorted(word_coefficient_tuples, key=lambda x:x[1], reverse=True)

# %%
word_coefficient_tuples
# Out:
# [('Im', 0.28054499999999499),
#  ('ltgt', 0.26628000000000202),
#  ('so', 0.24726000000000431),
#  ('got', 0.24726000000000431),
#  ('but', 0.24250500000000336),
#  ('like', 0.2329949999999969),
#  ('come', 0.22348500000000507),
#  ('do', 0.21397500000000236),
#  ('if', 0.21397500000000236),
#  ('Ill', 0.21397500000000236),
#  ('go', 0.20446499999999937),
#  ('day', 0.19495500000000227),
#  ('up', 0.19495500000000227),
#  ('need', 0.18068999999999769),
#  ('But', 0.17593499999999868),
#  ('think', 0.17118000000000319),
#  ('ok', 0.17118000000000319),
#  ('dont', 0.16642500000000049),
#  ('Ok', 0.16167000000000267),
#  ('lor', 0.16167000000000267),
#  ('time', 0.15691499999999872),
#  ('going', 0.15215999999999649),
#  ('about', 0.15215999999999649),
#  ('there', 0.15215999999999649),
#  ('know', 0.14740499999999968),
#  ('say', 0.1426499999999998),
#  ('So', 0.13789500000000299),
#  ('later', 0.13789500000000299),
#  ('Sorry', 0.13789500000000299),
#  ('much', 0.13789500000000299),
#  ('im', 0.13789500000000299),
#  ('still', 0.13314000000000101),
#  ('good', 0.13314000000000101),
#  ('already', 0.13314000000000101),
#  ('too', 0.13314000000000101),
#  ('was', 0.13314000000000101),
#  ('way', 0.12838499999999883),
#  ('love', 0.12363000000000215),
#  ('one', 0.12363000000000215),
#  ('sure', 0.12363000000000215),
#  ('all', 0.11887500000000009),
#  ('What', 0.11887500000000009),
#  ('said', 0.11887500000000009),
#  ('cant', 0.11887500000000009),
#  ('she', 0.11411999999999828),
#  ('some', 0.11411999999999828),
#  ('here', 0.10936500000000092),
#  ('night', 0.10936500000000092),
#  ('great', 0.10460999999999923),
#  ('ask', 0.099854999999998223),
#  ('him', 0.099854999999998223),
#  ('see', 0.099854999999998223),
#  ('da', 0.095100000000001697),
#  ('Not', 0.090344999999998843),
#  ('feel', 0.090344999999998843),
#  ('Its', 0.090344999999998843),
#  ('Did', 0.090344999999998843),
#  ('thats', 0.085590000000001595),
#  ('always', 0.085590000000001595),
#  ('really', 0.085590000000001595),
#  ('Are', 0.085590000000001595),
#  ('would', 0.085590000000001595),
#  ('And', 0.080835000000001336),
#  ('wait', 0.080835000000001336),
#  ('something', 0.080835000000001336),
#  ('lunch', 0.080835000000001336),
#  ('class', 0.080835000000001336),
#  ('work', 0.076079999999998246),
#  ('wont', 0.076079999999998246),
#  ('doing', 0.076079999999998246),
#  ('are', 0.076079999999998246),
#  ('ill', 0.076079999999998246),
#  ('late', 0.076079999999998246),
#  ('amp', 0.076079999999998246),
#  ('buy', 0.076079999999998246),
#  ('My', 0.071324999999999902),
#  ('pick', 0.071324999999999902),
#  ('car', 0.071324999999999902),
#  ('didnt', 0.071324999999999902),
#  ('lar', 0.071324999999999902),
#  ('finish', 0.071324999999999902),
#  ('Then', 0.071324999999999902),
#  ('Oh', 0.071324999999999902),
#  ('He', 0.071324999999999902),
#  ('down', 0.071324999999999902),
#  ('Yeah', 0.071324999999999902),
#  ('very', 0.066570000000000504),
#  ('few', 0.066570000000000504),
#  ('after', 0.066570000000000504),
#  ('also', 0.066570000000000504),
#  ('should', 0.066570000000000504),
#  ('where', 0.066570000000000504),
#  ('Hey', 0.066570000000000504),
#  ('dear', 0.066570000000000504),
#  ('right', 0.066570000000000504),
#  ('long', 0.066570000000000504),
#  ('happy', 0.066570000000000504),
#  ('did', 0.061815000000001077),
#  ('told', 0.061815000000001077),
#  ('When', 0.061815000000001077),
#  ('done', 0.061815000000001077),
#  ('tonight', 0.061815000000001077),
#  ('stuff', 0.061815000000001077),
#  ('Lol', 0.061815000000001077),
#  ('anything', 0.061815000000001077),
#  ('getting', 0.061815000000001077),
#  ('Ive', 0.061815000000001077),
#  ('again', 0.061815000000001077),
#  ('having', 0.061815000000001077),
#  ('Where', 0.057059999999999139),
#  ('hour', 0.057059999999999139),
#  ('things', 0.057059999999999139),
#  ('Haha', 0.057059999999999139),
#  ('place', 0.057059999999999139),
#  ('miss', 0.057059999999999139),
#  ('take', 0.057059999999999139),
#  ('Good', 0.057059999999999139),
#  ('hope', 0.057059999999999139),
#  ('morning', 0.057059999999999139),
#  ('life', 0.057059999999999139),
#  ('dat', 0.057059999999999139),
#  ('yet', 0.057059999999999139),
#  ('gonna', 0.057059999999999139),
#  ('guess', 0.057059999999999139),
#  ('sleep', 0.052304999999999616),
#  ('Yup', 0.052304999999999616),
#  ('let', 0.052304999999999616),
#  ('today', 0.052304999999999616),
#  ('before', 0.052304999999999616),
#  ('better', 0.052304999999999616),
#  ('went', 0.052304999999999616),
#  ('were', 0.052304999999999616),
#  ('Do', 0.052304999999999616),
#  ('pay', 0.052304999999999616),
#  ('Is', 0.052304999999999616),
#  ('money', 0.052304999999999616),
#  ('Happy', 0.052304999999999616),
#  ('around', 0.052304999999999616),
#  ('out', 0.052304999999999616),
#  ('nice', 0.052304999999999616),
#  ('sent', 0.047550000000000849),
#  ('Gud', 0.047550000000000849),
#  ('meet', 0.047550000000000849),
#  ('times', 0.047550000000000849),
#  ('Hope', 0.047550000000000849),
#  ('ya', 0.047550000000000849),
#  ('Can', 0.047550000000000849),
#  ('another', 0.047550000000000849),
#  ('lot', 0.047550000000000849),
#  ('thk', 0.047550000000000849),
#  ('plan', 0.047550000000000849),
#  ('job', 0.047550000000000849),
#  ('dun', 0.047550000000000849),
#  ('same', 0.047550000000000849),
#  ('youre', 0.047550000000000849),
#  ('It', 0.047550000000000849),
#  ('early', 0.047550000000000849),
#  ('wat', 0.047550000000000849),
#  ('til', 0.047550000000000849),
#  ('month', 0.042795000000000798),
#  ('run', 0.042795000000000798),
#  ('babe', 0.042795000000000798),
#  ('Yo', 0.042795000000000798),
#  ('coming', 0.042795000000000798),
#  ('man', 0.042795000000000798),
#  ('All', 0.042795000000000798),
#  ('doesnt', 0.042795000000000798),
#  ('princess', 0.042795000000000798),
#  ('hes', 0.042795000000000798),
#  ('thing', 0.042795000000000798),
#  ('first', 0.042795000000000798),
#  ('bed', 0.042795000000000798),
#  ('sat', 0.042795000000000798),
#  ('able', 0.042795000000000798),
#  ('Pls', 0.042795000000000798),
#  ('missing', 0.042795000000000798),
#  ('cos', 0.042795000000000798),
#  ('whole', 0.042795000000000798),
#  ('person', 0.042795000000000798),
#  ('If', 0.042795000000000798),
#  ('bit', 0.042795000000000798),
#  ('friends', 0.042795000000000798),
#  ('Well', 0.042795000000000798),
#  ('check', 0.042795000000000798),
#  ('once', 0.042795000000000798),
#  ('liao', 0.038039999999999123),
#  ('leave', 0.038039999999999123),
#  ('making', 0.038039999999999123),
#  ('change', 0.038039999999999123),
#  ('ME', 0.038039999999999123),
#  ('hurt', 0.038039999999999123),
#  ('account', 0.038039999999999123),
#  ('mail', 0.038039999999999123),
#  ('forgot', 0.038039999999999123),
#  ('keep', 0.038039999999999123),
#  ('than', 0.038039999999999123),
#  ('means', 0.038039999999999123),
#  ('She', 0.038039999999999123),
#  ('Thats', 0.038039999999999123),
#  ('meeting', 0.038039999999999123),
#  ('ive', 0.038039999999999123),
#  ('make', 0.038039999999999123),
#  ('other', 0.038039999999999123),
#  ('afternoon', 0.038039999999999123),
#  ('jus', 0.038039999999999123),
#  ('ah', 0.038039999999999123),
#  ('shit', 0.038039999999999123),
#  ('oso', 0.033285000000000252),
#  ('does', 0.033285000000000252),
#  ('smile', 0.033285000000000252),
#  ('Aight', 0.033285000000000252),
#  ('blue', 0.033285000000000252),
#  ('abt', 0.033285000000000252),
#  ('goes', 0.033285000000000252),
#  ('smoke', 0.033285000000000252),
#  ('MY', 0.033285000000000252),
#  ('two', 0.033285000000000252),
#  ('Ya', 0.033285000000000252),
#  ('remember', 0.033285000000000252),
#  ('might', 0.033285000000000252),
#  ('tomorrow', 0.033285000000000252),
#  ('though', 0.033285000000000252),
#  ('luv', 0.033285000000000252),
#  ('Were', 0.033285000000000252),
#  ('last', 0.033285000000000252),
#  ('sweet', 0.033285000000000252),
#  ('theres', 0.033285000000000252),
#  ('yesterday', 0.033285000000000252),
#  ('off', 0.033285000000000252),
#  ('makes', 0.033285000000000252),
#  ('Thanx', 0.033285000000000252),
#  ('world', 0.033285000000000252),
#  ('ltDECIMALgt', 0.033285000000000252),
#  ('shall', 0.033285000000000252),
#  ('everything', 0.033285000000000252),
#  ('prob', 0.033285000000000252),
#  ('Hello', 0.033285000000000252),
#  ('dinner', 0.033285000000000252),
#  ('bus', 0.033285000000000252),
#  ('made', 0.033285000000000252),
#  ('tv', 0.02852999999999957),
#  ('cool', 0.02852999999999957),
#  ('school', 0.02852999999999957),
#  ('full', 0.02852999999999957),
#  ('leh', 0.02852999999999957),
#  ('family', 0.02852999999999957),
#  ('working', 0.02852999999999957),
#  ('figure', 0.02852999999999957),
#  ('sir', 0.02852999999999957),
#  ('Missing', 0.02852999999999957),
#  ('boytoy', 0.02852999999999957),
#  ('Will', 0.02852999999999957),
#  ('office', 0.02852999999999957),
#  ('isnt', 0.02852999999999957),
#  ('break', 0.02852999999999957),
#  ('girl', 0.02852999999999957),
#  ('special', 0.02852999999999957),
#  ('driving', 0.02852999999999957),
#  ('quite', 0.02852999999999957),
#  ('put', 0.02852999999999957),
#  ('kiss', 0.02852999999999957),
#  ('Going', 0.02852999999999957),
#  ('anyone', 0.02852999999999957),
#  ('They', 0.02852999999999957),
#  ('pain', 0.02852999999999957),
#  ('most', 0.02852999999999957),
#  ('drive', 0.02852999999999957),
#  ('fine', 0.02852999999999957),
#  ('busy', 0.02852999999999957),
#  ('de', 0.02852999999999957),
#  ('watch', 0.02852999999999957),
#  ('words', 0.02852999999999957),
#  ('bad', 0.02852999999999957),
#  ('enough', 0.02852999999999957),
#  ('many', 0.02852999999999957),
#  ('Was', 0.02852999999999957),
#  ('treat', 0.02852999999999957),
#  ('lect', 0.02852999999999957),
#  ('Cos', 0.02852999999999957),
#  ('thought', 0.02852999999999957),
#  ('In', 0.02852999999999957),
#  ('thinking', 0.02852999999999957),
#  ('because', 0.02852999999999957),
#  ('hair', 0.02852999999999957),
#  ('tmr', 0.02852999999999957),
#  ('plz', 0.02852999999999957),
#  ('Melle', 0.02852999999999957),
#  ('wan', 0.02852999999999957),
#  ('pa', 0.02852999999999957),
#  ('head', 0.02852999999999957),
#  ('problem', 0.02852999999999957),
#  ('evening', 0.02852999999999957),
#  ('felt', 0.02852999999999957),
#  ('stay', 0.02852999999999957),
#  ('Does', 0.023775000000000424),
#  ('anyway', 0.023775000000000424),
#  ('says', 0.023775000000000424),
#  ('second', 0.023775000000000424),
#  ('net', 0.023775000000000424),
#  ('Alright', 0.023775000000000424),
#  ('Abiola', 0.023775000000000424),
#  ('ahead', 0.023775000000000424),
#  ('baby', 0.023775000000000424),
#  ('den', 0.023775000000000424),
#  ('heart', 0.023775000000000424),
#  ('aft', 0.023775000000000424),
#  ('soon', 0.023775000000000424),
#  ('happened', 0.023775000000000424),
#  ('noe', 0.023775000000000424),
#  ('weight', 0.023775000000000424),
#  ('house', 0.023775000000000424),
#  ('open', 0.023775000000000424),
#  ('ha', 0.023775000000000424),
#  ('story', 0.023775000000000424),
#  ('care', 0.023775000000000424),
#  ('could', 0.023775000000000424),
#  ('little', 0.023775000000000424),
#  ('wonderful', 0.023775000000000424),
#  ('took', 0.023775000000000424),
#  ('saw', 0.023775000000000424),
#  ('bring', 0.023775000000000424),
#  ('Smile', 0.023775000000000424),
#  ('meant', 0.023775000000000424),
#  ('college', 0.023775000000000424),
#  ('That', 0.023775000000000424),
#  ('exam', 0.023775000000000424),
#  ('point', 0.023775000000000424),
#  ('wake', 0.023775000000000424),
#  ('case', 0.023775000000000424),
#  ('myself', 0.023775000000000424),
#  ('Dont', 0.023775000000000424),
#  ('Any', 0.023775000000000424),
#  ('askd', 0.023775000000000424),
#  ('itself', 0.023775000000000424),
#  ('ready', 0.023775000000000424),
#  ('IM', 0.023775000000000424),
#  ('Thank', 0.023775000000000424),
#  ('cut', 0.023775000000000424),
#  ('hav', 0.023775000000000424),
#  ('big', 0.023775000000000424),
#  ('people', 0.023775000000000424),
#  ('towards', 0.023775000000000424),
#  ('Let', 0.023775000000000424),
#  ('oh', 0.023775000000000424),
#  ('tomo', 0.023775000000000424),
#  ('Hmmm', 0.023775000000000424),
#  ('bath', 0.023775000000000424),
#  ('promise', 0.023775000000000424),
#  ('lesson', 0.023775000000000424),
#  ('happen', 0.023775000000000424),
#  ('called', 0.023775000000000424),
#  ('test', 0.023775000000000424),
#  ('AT', 0.023775000000000424),
#  ('ago', 0.023775000000000424),
#  ('sch', 0.019019999999999562),
#  ('chennai', 0.019019999999999562),
#  ('ticket', 0.019019999999999562),
#  ('havent', 0.019019999999999562),
#  ('dis', 0.019019999999999562),
#  ('tired', 0.019019999999999562),
#  ('Me', 0.019019999999999562),
#  ('pub', 0.019019999999999562),
#  ('wif', 0.019019999999999562),
#  ('wit', 0.019019999999999562),
#  ('usf', 0.019019999999999562),
#  ('until', 0.019019999999999562),
#  ('knows', 0.019019999999999562),
#  ('started', 0.019019999999999562),
#  ('company', 0.019019999999999562),
#  ('hold', 0.019019999999999562),
#  ('LIKE', 0.019019999999999562),
#  ('watching', 0.019019999999999562),
#  ('pizza', 0.019019999999999562),
#  ('birthday', 0.019019999999999562),
#  ('mah', 0.019019999999999562),
#  ('maybe', 0.019019999999999562),
#  ('Watching', 0.019019999999999562),
#  ('talk', 0.019019999999999562),
#  ('Same', 0.019019999999999562),
#  ('paper', 0.019019999999999562),
#  ('hell', 0.019019999999999562),
#  ('wun', 0.019019999999999562),
#  ('URN', 0.019019999999999562),
#  ('half', 0.019019999999999562),
#  ('mrng', 0.019019999999999562),
#  ('someone', 0.019019999999999562),
#  ('rock', 0.019019999999999562),
#  ('side', 0.019019999999999562),
#  ('carlos', 0.019019999999999562),
#  ('mean', 0.019019999999999562),
#  ('cause', 0.019019999999999562),
#  ('wanted', 0.019019999999999562),
#  ('Ugh', 0.019019999999999562),
#  ('dunno', 0.019019999999999562),
#  ('swing', 0.019019999999999562),
#  ('There', 0.019019999999999562),
#  ('yourself', 0.019019999999999562),
#  ('reached', 0.019019999999999562),
#  ('tot', 0.019019999999999562),
#  ('copy', 0.019019999999999562),
#  ('kind', 0.019019999999999562),
#  ('bored', 0.019019999999999562),
#  ('Love', 0.019019999999999562),
#  ('Come', 0.019019999999999562),
#  ('matter', 0.019019999999999562),
#  ('supposed', 0.019019999999999562),
#  ('ard', 0.019019999999999562),
#  ('feeling', 0.019019999999999562),
#  ('mind', 0.019019999999999562),
#  ('sad', 0.019019999999999562),
#  ('talking', 0.019019999999999562),
#  ('Got', 0.019019999999999562),
#  ('sell', 0.019019999999999562),
#  ('online', 0.019019999999999562),
#  ('Thk', 0.019019999999999562),
#  ('nothing', 0.019019999999999562),
#  ('mrt', 0.019019999999999562),
#  ('came', 0.019019999999999562),
#  ('saying', 0.019019999999999562),
#  ('show', 0.019019999999999562),
#  ('Wen', 0.019019999999999562),
#  ('outside', 0.019019999999999562),
#  ('pretty', 0.019019999999999562),
#  ('Once', 0.019019999999999562),
#  ('worries', 0.019019999999999562),
#  ('decided', 0.019019999999999562),
#  ('sea', 0.019019999999999562),
#  ('close', 0.019019999999999562),
#  ('lots', 0.019019999999999562),
#  ('movie', 0.019019999999999562),
#  ('Plz', 0.019019999999999562),
#  ('rite', 0.019019999999999562),
#  ('reading', 0.019019999999999562),
#  ('youll', 0.019019999999999562),
#  ('trust', 0.019019999999999562),
#  ('light', 0.019019999999999562),
#  ('fri', 0.019019999999999562),
#  ('Jus', 0.019019999999999562),
#  ('HEY', 0.019019999999999562),
#  ('situation', 0.019019999999999562),
#  ('sleeping', 0.019019999999999562),
#  ('worry', 0.019019999999999562),
#  ('anymore', 0.019019999999999562),
#  ('food', 0.019019999999999562),
#  ('gets', 0.019019999999999562),
#  ('drink', 0.019019999999999562),
#  ('hand', 0.019019999999999562),
#  ('without', 0.019019999999999562),
#  ('spend', 0.019019999999999562),
#  ('sec', 0.019019999999999562),
#  ('just', 0.019019999999999562),
#  ('less', 0.019019999999999562),
#  ('happiness', 0.019019999999999562),
#  ('gave', 0.019019999999999562),
#  ('fucking', 0.019019999999999562),
#  ('HAPPY', 0.019019999999999562),
#  ('confirm', 0.019019999999999562),
#  ('Nothing', 0.019019999999999562),
#  ('First', 0.019019999999999562),
#  ('Kate', 0.019019999999999562),
#  ('wanna', 0.019019999999999562),
#  ('road', 0.019019999999999562),
#  ('TIME', 0.019019999999999562),
#  ('start', 0.019019999999999562),
#  ('Every', 0.019019999999999562),
#  ('tho', 0.019019999999999562),
#  ('buying', 0.019019999999999562),
#  ('Awesome', 0.019019999999999562),
#  ('minutes', 0.019019999999999562),
#  ('sick', 0.019019999999999562),
#  ('monday', 0.019019999999999562),
#  ('8th', 0.019019999999999562),
#  ('finally', 0.014264999999999785),
#  ('eve', 0.014264999999999785),
#  ('giving', 0.014264999999999785),
#  ('met', 0.014264999999999785),
#  ('sort', 0.014264999999999785),
#  ('must', 0.014264999999999785),
#  ('town', 0.014264999999999785),
#  ('end', 0.014264999999999785),
#  ('bout', 0.014264999999999785),
#  ('hard', 0.014264999999999785),
#  ('used', 0.014264999999999785),
#  ('saturday', 0.014264999999999785),
#  ('try', 0.014264999999999785),
#  ('Whats', 0.014264999999999785),
#  ('left', 0.014264999999999785),
#  ('menu', 0.014264999999999785),
#  ('while', 0.014264999999999785),
#  ('Tell', 0.014264999999999785),
#  ('touch', 0.014264999999999785),
#  ('OF', 0.014264999999999785),
#  ('ring', 0.014264999999999785),
#  ('pls', 0.014264999999999785),
#  ('wish', 0.014264999999999785),
#  ('Sir', 0.014264999999999785),
#  ('May', 0.014264999999999785),
#  ('book', 0.014264999999999785),
#  ('Am', 0.014264999999999785),
#  ('Today', 0.0095099999999997808),
#  ('gettin', 0.0095099999999997808),
#  ('download', 0.0095099999999997808),
#  ('sending', 0.0095099999999997808),
#  ('use', 0.0095099999999997808),
#  ('reach', 0.0095099999999997808),
#  ('best', 0.0095099999999997808),
#  ('being', 0.0095099999999997808),
#  ('Or', 0.0095099999999997808),
#  ('believe', 0.0095099999999997808),
#  ('Great', 0.0095099999999997808),
#  ('via', 0.0047549999999998904),
#  ('till', 0.0047549999999998904),
#  ('Why', 0.0047549999999998904),
#  ('guys', 0.0047549999999998904),
#  ('they', 0.0047549999999998904),
#  ('comes', 0.0047549999999998904),
#  ('address', 0.0047549999999998904),
#  ('xxx', 0.0047549999999998904),
#  ('IN', 0.0047549999999998904),
#  ('real', 0.0047549999999998904),
#  ('back', 0.0047549999999998904),
#  ('Hi', 0.0047549999999998904),
#  ('NO', 0.0047549999999998904),
#  ('hear', 0.0047549999999998904),
#  ('year', 0.0047549999999998904),
#  ('1500', 0.0),
#  ('900', 0.0),
#  ('', 0.0),
#  ('3wk', 0.0),
#  ('', 0.0),
#  ('Cost150pm', 0.0),
#  ('months', 0.0),
#  ('', 0.0),
#  ('weekend', 0.0),
#  ('Enjoy', -0.0047549999999998904),
#  ('Go', -0.0047549999999998904),
#  ('Cant', -0.0047549999999998904),
#  ('years', -0.0047549999999998904),
#  ('choose', -0.0047549999999998904),
#  ('name', -0.0047549999999998904),
#  ('looking', -0.0047549999999998904),
#  ('away', -0.0047549999999998904),
#  ('400', -0.0047549999999998904),
#  ('speak', -0.0047549999999998904),
#  ('into', -0.0047549999999998904),
#  ('question', -0.0047549999999998904),
#  ('2000', -0.0095099999999997808),
#  ('Just', -0.0095099999999997808),
#  ('takes', -0.0095099999999997808),
#  ('msg', -0.0095099999999997808),
#  ('b4', -0.0095099999999997808),
#  ('2day', -0.0095099999999997808),
#  ('log', -0.0095099999999997808),
#  ('girls', -0.0095099999999997808),
#  ('350', -0.0095099999999997808),
#  ('invited', -0.0095099999999997808),
#  ('10000', -0.0095099999999997808),
#  ('THE', -0.0095099999999997808),
#  ('Check', -0.0095099999999997808),
#  ('hours', -0.0095099999999997808),
#  ('shopping', -0.0095099999999997808),
#  ('wid', -0.0095099999999997808),
#  ('game', -0.0095099999999997808),
#  ('ON', -0.0095099999999997808),
#  ('cost', -0.014264999999999785),
#  ('picked', -0.014264999999999785),
#  ('pass', -0.014264999999999785),
#  ('by', -0.014264999999999785),
#  ('more', -0.014264999999999785),
#  ('DATE', -0.014264999999999785),
#  ('Our', -0.014264999999999785),
#  ('country', -0.014264999999999785),
#  ('date', -0.014264999999999785),
#  ('Thanks', -0.014264999999999785),
#  ('calling', -0.014264999999999785),
#  ('rply', -0.014264999999999785),
#  ('goto', -0.014264999999999785),
#  ('fancy', -0.014264999999999785),
#  ('friend', -0.014264999999999785),
#  ('fone', -0.014264999999999785),
#  ('sms', -0.014264999999999785),
#  ('Help', -0.014264999999999785),
#  ('questions', -0.014264999999999785),
#  ('ends', -0.014264999999999785),
#  ('terms', -0.014264999999999785),
#  ('login', -0.014264999999999785),
#  ('asked', -0.014264999999999785),
#  ('entered', -0.014264999999999785),
#  ('lets', -0.014264999999999785),
#  ('match', -0.014264999999999785),
#  ('ans', -0.014264999999999785),
#  ('450', -0.014264999999999785),
#  ('XXX', -0.014264999999999785),
#  ('trip', -0.014264999999999785),
#  ('LOVE', -0.014264999999999785),
#  ('cum', -0.014264999999999785),
#  ('200', -0.014264999999999785),
#  ('urgent', -0.014264999999999785),
#  ('immediately', -0.014264999999999785),
#  ('plus', -0.014264999999999785),
#  ('computer', -0.014264999999999785),
#  ('FROM', -0.014264999999999785),
#  ('daily', -0.014264999999999785),
#  ('Sky', -0.019019999999999562),
#  ('Pound', -0.019019999999999562),
#  ('nokia', -0.019019999999999562),
#  ('Terms', -0.019019999999999562),
#  ('Should', -0.019019999999999562),
#  ('9AE', -0.019019999999999562),
#  ('CAMERA', -0.019019999999999562),
#  ('SIM', -0.019019999999999562),
#  ('Gift', -0.019019999999999562),
#  ('Ibiza', -0.019019999999999562),
#  ('FLAG', -0.019019999999999562),
#  ('Wkly', -0.019019999999999562),
#  ('9am11pm', -0.019019999999999562),
#  ('SPTyrone', -0.019019999999999562),
#  ('credit', -0.019019999999999562),
#  ('150pmin', -0.019019999999999562),
#  ('app', -0.019019999999999562),
#  ('RowW1JHL', -0.019019999999999562),
#  ('REVEAL', -0.019019999999999562),
#  ('ec2a', -0.019019999999999562),
#  ('flag', -0.019019999999999562),
#  ('2optout', -0.019019999999999562),
#  ('yer', -0.019019999999999562),
#  ('Xmas', -0.019019999999999562),
#  ('purpose', -0.019019999999999562),
#  ('CW25WX', -0.019019999999999562),
#  ('lucky', -0.019019999999999562),
#  ('Netcollex', -0.019019999999999562),
#  ('Speak', -0.019019999999999562),
#  ('DOUBLE', -0.019019999999999562),
#  ('tkts', -0.019019999999999562),
#  ('fromm', -0.019019999999999562),
#  ('Santa', -0.019019999999999562),
#  ('SERVICES', -0.019019999999999562),
#  ('Msg', -0.019019999999999562),
#  ('logo', -0.019019999999999562),
#  ('Tenants', -0.019019999999999562),
#  ('wwwringtonescouk', -0.019019999999999562),
#  ('ENG', -0.019019999999999562),
#  ('Break', -0.019019999999999562),
#  ('txtin', -0.019019999999999562),
#  ('review', -0.019019999999999562),
#  ('10am7pm', -0.019019999999999562),
#  ('Loyalty', -0.019019999999999562),
#  ('POD', -0.019019999999999562),
#  ('With', -0.019019999999999562),
#  ('singles', -0.019019999999999562),
#  ('7250i', -0.019019999999999562),
#  ('TV', -0.019019999999999562),
#  ('Shopping', -0.019019999999999562),
#  ('STORE', -0.019019999999999562),
#  ('NAME', -0.019019999999999562),
#  ('ringtones', -0.019019999999999562),
#  ('5we', -0.019019999999999562),
#  ('answer', -0.019019999999999562),
#  ('Box39822', -0.019019999999999562),
#  ('4info', -0.019019999999999562),
#  ('FANTASTIC', -0.019019999999999562),
#  ('COLLECT', -0.019019999999999562),
#  ('ip4', -0.019019999999999562),
#  ('conditions', -0.019019999999999562),
#  ('150pMsgrcvdHGSuite3422LandsRowW1J6HL', -0.019019999999999562),
#  ('sport', -0.019019999999999562),
#  ('Vodafone', -0.019019999999999562),
#  ('store', -0.019019999999999562),
#  ('contract', -0.019019999999999562),
#  ('wap', -0.019019999999999562),
#  ('Forwarded', -0.019019999999999562),
#  ('cancel', -0.019019999999999562),
#  ('5000', -0.019019999999999562),
#  ('inclusive', -0.019019999999999562),
#  ('TXTAUCTION', -0.019019999999999562),
#  ('gay', -0.019019999999999562),
#  ('mths', -0.019019999999999562),
#  ('fun', -0.019019999999999562),
#  ('largest', -0.019019999999999562),
#  ('SHOP', -0.019019999999999562),
#  ('ntwk', -0.019019999999999562),
#  ('records', -0.019019999999999562),
#  ('summer', -0.019019999999999562),
#  ('BT', -0.019019999999999562),
#  ('M263UZ', -0.019019999999999562),
#  ('unlimited', -0.019019999999999562),
#  ('Unsub', -0.019019999999999562),
#  ('3mins', -0.019019999999999562),
#  ('England', -0.019019999999999562),
#  ('London', -0.019019999999999562),
#  ('3GBP', -0.019019999999999562),
#  ('VIP', -0.019019999999999562),
#  ('original', -0.019019999999999562),
#  ('FA', -0.019019999999999562),
#  ('exciting', -0.019019999999999562),
#  ('3qxj9', -0.019019999999999562),
#  ('2nite', -0.019019999999999562),
#  ('1000s', -0.019019999999999562),
#  ('ppm', -0.019019999999999562),
#  ('W111WX', -0.019019999999999562),
#  ('ac', -0.019019999999999562),
#  ('handset', -0.019019999999999562),
#  ('10', -0.019019999999999562),
#  ('bx420', -0.019019999999999562),
#  ('details', -0.019019999999999562),
#  ('ansr', -0.019019999999999562),
#  ('important', -0.019019999999999562),
#  ('60pmin', -0.019019999999999562),
#  ('POBOX84', -0.019019999999999562),
#  ('calls', -0.019019999999999562),
#  ('Fancy', -0.019019999999999562),
#  ('O2', -0.023775000000000424),
#  ('minute', -0.023775000000000424),
#  ('TO', -0.023775000000000424),
#  ('videochat', -0.023775000000000424),
#  ('rentl', -0.023775000000000424),
#  ('3G', -0.023775000000000424),
#  ('Calls', -0.023775000000000424),
#  ('Videophones', -0.023775000000000424),
#  ('httpwwwurawinnercom', -0.023775000000000424),
#  ('music', -0.023775000000000424),
#  ('150ptone', -0.023775000000000424),
#  ('quoting', -0.023775000000000424),
#  ('following', -0.023775000000000424),
#  ('YOUR', -0.023775000000000424),
#  ('information', -0.023775000000000424),
#  ('150pMsg', -0.023775000000000424),
#  ('age16', -0.023775000000000424),
#  ('noline', -0.023775000000000424),
#  ('Gr8', -0.023775000000000424),
#  ('SonyEricsson', -0.023775000000000424),
#  ('300', -0.023775000000000424),
#  ('POBox36504W45WQ', -0.023775000000000424),
#  ('ENGLAND', -0.023775000000000424),
#  ('From', -0.023775000000000424),
#  ('re', -0.023775000000000424),
#  ('IS', -0.023775000000000424),
#  ('onto', -0.023775000000000424),
#  ('revealed', -0.023775000000000424),
#  ('250', -0.023775000000000424),
#  ('locations', -0.023775000000000424),
#  ('Price', -0.023775000000000424),
#  ('enter', -0.023775000000000424),
#  ('wwwcomuknet', -0.023775000000000424),
#  ('selection', -0.023775000000000424),
#  ('contacted', -0.023775000000000424),
#  ('Ringtone', -0.023775000000000424),
#  ('PC', -0.023775000000000424),
#  ('Mob', -0.023775000000000424),
#  ('local', -0.023775000000000424),
#  ('National', -0.023775000000000424),
#  ('Voda', -0.023775000000000424),
#  ('news', -0.023775000000000424),
#  ('HOT', -0.023775000000000424),
#  ('Guess', -0.023775000000000424),
#  ('Play', -0.023775000000000424),
#  ('java', -0.023775000000000424),
#  ('pic', -0.023775000000000424),
#  ('CDs', -0.023775000000000424),
#  ('Co', -0.023775000000000424),
#  ('FANTASIES', -0.023775000000000424),
#  ('partner', -0.023775000000000424),
#  ('member', -0.023775000000000424),
#  ('XCHAT', -0.023775000000000424),
#  ('Service', -0.023775000000000424),
#  ('extra', -0.023775000000000424),
#  ('GET', -0.023775000000000424),
#  ('Sub', -0.023775000000000424),
#  ('MP3', -0.023775000000000424),
#  ('Auction', -0.023775000000000424),
#  ('Holder', -0.023775000000000424),
#  ('3510i', -0.023775000000000424),
#  ('December', -0.023775000000000424),
#  ('1x150pwk', -0.023775000000000424),
#  ('Dload', -0.023775000000000424),
#  ('Games', -0.023775000000000424),
#  ('Luv', -0.023775000000000424),
#  ('Chance', -0.023775000000000424),
#  ('official', -0.023775000000000424),
#  ('ASAP', -0.023775000000000424),
#  ('awaiting', -0.023775000000000424),
#  ('Cash', -0.023775000000000424),
#  ('Someone', -0.02852999999999957),
#  ('toClaim', -0.02852999999999957),
#  ('ONLY', -0.02852999999999957),
#  ('waiting', -0.02852999999999957),
#  ('Dear', -0.02852999999999957),
#  ('Uve', -0.02852999999999957),
#  ('POLY', -0.02852999999999957),
#  ('FRND', -0.02852999999999957),
#  ('Day', -0.02852999999999957),
#  ('arrive', -0.02852999999999957),
#  ('Digital', -0.02852999999999957),
#  ('UNLIMITED', -0.02852999999999957),
#  ('POBox334', -0.02852999999999957),
#  ('help', -0.02852999999999957),
#  ('vary', -0.02852999999999957),
#  ('W45WQ', -0.02852999999999957),
#  ('POBOX', -0.02852999999999957),
#  ('Delivery', -0.02852999999999957),
#  ('part', -0.02852999999999957),
#  ('Stockport', -0.02852999999999957),
#  ('flights', -0.02852999999999957),
#  ('150pm', -0.02852999999999957),
#  ('SK38xh', -0.02852999999999957),
#  ('any', -0.02852999999999957),
#  ('min', -0.02852999999999957),
#  ('link', -0.02852999999999957),
#  ('zed', -0.02852999999999957),
#  ('weekends', -0.02852999999999957),
#  ('sex', -0.02852999999999957),
#  ('1000', -0.02852999999999957),
#  ('Optout', -0.02852999999999957),
#  ('CC', -0.02852999999999957),
#  ('standard', -0.02852999999999957),
#  ('WAP', -0.02852999999999957),
#  ('user', -0.02852999999999957),
#  ('Wanna', -0.02852999999999957),
#  ('TnCs', -0.02852999999999957),
#  ('announcement', -0.02852999999999957),
#  ('polys', -0.02852999999999957),
#  ('Max10mins', -0.02852999999999957),
#  ('Arcade', -0.02852999999999957),
#  ('HL', -0.02852999999999957),
#  ('update', -0.02852999999999957),
#  ('inviting', -0.02852999999999957),
#  ('tariffs', -0.02852999999999957),
#  ('within', -0.02852999999999957),
#  ('XMAS', -0.02852999999999957),
#  ('trying', -0.02852999999999957),
#  ('Voucher', -0.02852999999999957),
#  ('Choose', -0.02852999999999957),
#  ('replying', -0.02852999999999957),
#  ('40GB', -0.02852999999999957),
#  ('SiPix', -0.02852999999999957),
#  ('area', -0.02852999999999957),
#  ('norm150ptone', -0.02852999999999957),
#  ('Saturday', -0.02852999999999957),
#  ('AGE', -0.033285000000000252),
#  ('access', -0.033285000000000252),
#  ('pics', -0.033285000000000252),
#  ('visit', -0.033285000000000252),
#  ('join', -0.033285000000000252),
#  ('spree', -0.033285000000000252),
#  ('hot', -0.033285000000000252),
#  ('rcvd', -0.033285000000000252),
#  ('Sol', -0.033285000000000252),
#  ('Welcome', -0.033285000000000252),
#  ('LDN', -0.033285000000000252),
#  ('days', -0.033285000000000252),
#  ('Croydon', -0.033285000000000252),
#  ('20p', -0.033285000000000252),
#  ('find', -0.033285000000000252),
#  ('5WB', -0.033285000000000252),
#  ('See', -0.033285000000000252),
#  ('national', -0.033285000000000252),
#  ('horny', -0.033285000000000252),
#  ('Sony', -0.033285000000000252),
#  ('cashin', -0.033285000000000252),
#  ('CR9', -0.033285000000000252),
#  ('etc', -0.033285000000000252),
#  ('Join', -0.033285000000000252),
#  ('Landline', -0.033285000000000252),
#  ('maximize', -0.033285000000000252),
#  ('secret', -0.033285000000000252),
#  ('camcorder', -0.033285000000000252),
#  ('charity', -0.033285000000000252),
#  ('custcare', -0.033285000000000252),
#  ('HGSuite3422Lands', -0.033285000000000252),
#  ('DVD', -0.033285000000000252),
#  ('bid', -0.033285000000000252),
#  ('Half', -0.033285000000000252),
#  ('each', -0.033285000000000252),
#  ('next', -0.033285000000000252),
#  ('offer', -0.033285000000000252),
#  ('inc', -0.033285000000000252),
#  ('Sunshine', -0.033285000000000252),
#  ('cashbalance', -0.033285000000000252),
#  ('Tenerife', -0.033285000000000252),
#  ('Costa', -0.033285000000000252),
#  ('TEXT', -0.038039999999999123),
#  ('No1', -0.038039999999999123),
#  ('Ufind', -0.038039999999999123),
#  ('direct', -0.038039999999999123),
#  ('Camcorder', -0.038039999999999123),
#  ('auction', -0.038039999999999123),
#  ('Rreveal', -0.038039999999999123),
#  ('charge', -0.038039999999999123),
#  ('iPod', -0.038039999999999123),
#  ('messages', -0.038039999999999123),
#  ('admirer', -0.038039999999999123),
#  ('UKs', -0.038039999999999123),
#  ('GO', -0.038039999999999123),
#  ('either', -0.038039999999999123),
#  ('FREEPHONE', -0.038039999999999123),
#  ('play', -0.038039999999999123),
#  ('Del', -0.038039999999999123),
#  ('ending', -0.038039999999999123),
#  ('CD', -0.038039999999999123),
#  ('25p', -0.038039999999999123),
#  ('BTnationalrate', -0.038039999999999123),
#  ('entitled', -0.038039999999999123),
#  ('matches', -0.038039999999999123),
#  ('Tones', -0.038039999999999123),
#  ('poly', -0.038039999999999123),
#  ('reward', -0.038039999999999123),
#  ('Phone', -0.038039999999999123),
#  ('info', -0.038039999999999123),
#  ('OUT', -0.038039999999999123),
#  ('club', -0.038039999999999123),
#  ('Customer', -0.038039999999999123),
#  ('specialcall', -0.038039999999999123),
#  ('More', -0.042795000000000798),
#  ('Last', -0.042795000000000798),
#  ('specially', -0.042795000000000798),
#  ('discount', -0.042795000000000798),
#  ('wwwgetzedcouk', -0.042795000000000798),
#  ('numbers', -0.042795000000000798),
#  ('11mths', -0.042795000000000798),
#  ('order', -0.042795000000000798),
#  ('rental', -0.042795000000000798),
#  ('rates', -0.042795000000000798),
#  ('std', -0.042795000000000798),
#  ('Club', -0.042795000000000798),
#  ('price', -0.042795000000000798),
#  ('Mins', -0.042795000000000798),
#  ('Want', -0.042795000000000798),
#  ('Bluetooth', -0.042795000000000798),
#  ('between', -0.042795000000000798),
#  ('FOR', -0.042795000000000798),
#  ('Stop', -0.042795000000000798),
#  ('BOX', -0.042795000000000798),
#  ('thinks', -0.042795000000000798),
#  ('Dogging', -0.042795000000000798),
#  ('txting', -0.042795000000000798),
#  ('credits', -0.042795000000000798),
#  ('NEW', -0.042795000000000798),
#  ('FreeMsg', -0.042795000000000798),
#  ('Tone', -0.042795000000000798),
#  ('mobiles', -0.042795000000000798),
#  ('content', -0.047550000000000849),
#  ('Latest', -0.047550000000000849),
#  ('worth', -0.047550000000000849),
#  ('yr', -0.047550000000000849),
#  ('voucher', -0.047550000000000849),
#  ('player', -0.047550000000000849),
#  ('NTT', -0.047550000000000849),
#  ('Video', -0.047550000000000849),
#  ('MUSIC', -0.047550000000000849),
#  ('HMV', -0.047550000000000849),
#  ('holiday', -0.047550000000000849),
#  ('POBox', -0.047550000000000849),
#  ('Chat', -0.047550000000000849),
#  ('10pmin', -0.047550000000000849),
#  ('final', -0.047550000000000849),
#  ('txts', -0.047550000000000849),
#  ('comp', -0.047550000000000849),
#  ('representative', -0.047550000000000849),
#  ('Camera', -0.047550000000000849),
#  ('opt', -0.047550000000000849),
#  ('LIVE', -0.047550000000000849),
#  ('TXT', -0.047550000000000849),
#  ('wkly', -0.047550000000000849),
#  ('Quiz', -0.047550000000000849),
#  ('New', -0.047550000000000849),
#  ('Caller', -0.047550000000000849),
#  ('Congrats', -0.047550000000000849),
#  ('currently', -0.047550000000000849),
#  ('150pmsg', -0.047550000000000849),
#  ('code', -0.052304999999999616),
#  ('phones', -0.052304999999999616),
#  ('charged', -0.052304999999999616),
#  ('valued', -0.052304999999999616),
#  ('anytime', -0.052304999999999616),
#  ('top', -0.052304999999999616),
#  ('please', -0.052304999999999616),
#  ('games', -0.052304999999999616),
#  ('easy', -0.052304999999999616),
#  ('Motorola', -0.052304999999999616),
#  ('Update', -0.057059999999999139),
#  ('complimentary', -0.057059999999999139),
#  ('eg', -0.057059999999999139),
#  ('3', -0.057059999999999139),
#  ('Only', -0.057059999999999139),
#  ('colour', -0.057059999999999139),
#  ('points', -0.057059999999999139),
#  ('winner', -0.057059999999999139),
#  ('weeks', -0.057059999999999139),
#  ('150', -0.057059999999999139),
#  ('services', -0.057059999999999139),
#  ('Double', -0.057059999999999139),
#  ('TONE', -0.061815000000001077),
#  ('Congratulations', -0.061815000000001077),
#  ('offers', -0.061815000000001077),
#  ('Cs', -0.061815000000001077),
#  ('mates', -0.061815000000001077),
#  ('yours', -0.061815000000001077),
#  ('wk', -0.061815000000001077),
#  ('Offer', -0.061815000000001077),
#  ('gift', -0.061815000000001077),
#  ...]
